# %%
# !pip install PyMuPDF pytesseract Pillow --quiet

# %%
import pytesseract

print(pytesseract)
# Out:
# <module 'pytesseract' from 'C:\\Users\\aswin\\anaconda3\\Lib\\site-packages\\pytesseract\\__init__.py'>

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

import fitz  # PyMuPDF
from PIL import Image
import pytesseract

# Define the path to the PDF file
pdf_path = r'C:\Users\aswin\OneDrive\Desktop\Important\Presentations\ML\Data\Form_Data\12559_Aswin_Bhaskaran.pdf'

# Open the PDF file
pdf_document = fitz.open(pdf_path)

# Iterate through each page
for page_num in range(pdf_document.page_count):
    page = pdf_document.load_page(page_num)
    pix = page.get_pixmap()
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

    # Perform OCR on the image
    text = pytesseract.image_to_string(img)

    # Print the extracted text
    print(f"Page {page_num + 1}:\n{text}\n")

# Close the PDF document
pdf_document.close()
# Out:
# Page 1:
# Zoom
#
# {TV ihn Cre DUT & Deenive Driving Shoot
# £908 Sate Brie Ra, St
#
# No 12559
#
# Jobns Creek, Georgia 30097 — Hats ——|
# ‘elepbone 70) a1-0909 ge
#
# Driver Improvement Student Contract
#
# Name: _Aswin Bhaskaran _ Daewrotciss gliglay
#
# Aatess: SBE Suwaree Green Biya —Timo(s)ofCiass: _10130-$150 a
# Cty Sate, Zp: Suwannee, GA 0024 —_CisssLocalon’ sommes 200004
#
# oateorsen; tba _— Comveniont pts
# Social Security # Amount Pais: $45 [online 124 yosa
#
# Driver's Liconse # __058866481
#
# Teleshone No: 18.2 S70 -G1OZEMai Address: _ASWINaUsegmail. com
#
# |. te undersigned student. agro compl the above couse, consisting of. ‘ cassestor_©
# hours each, iang__fe_ hers ofsteten by he atove-cae ver ngrremen Cine Wl uated a ie now
# ‘eens he Gora Depron of Over Senn (008) scrdane with ea Law Te 408-00 (ORWER PROVEMENT ACT)
# ‘nde des ad regulations aoe hr nde and ht each neo afd ty he OOS. Ta cua approved by ne DOS
# ‘he stent's successful completion of he above-named course require acho the flowing
#
# ‘Attendance at all asses sober sr fe from ck rugs.
# ‘Atendance on tne fora senor
#
# Reasonable alteiveness and parcipaon na castes,
#
# ‘Atendance aa sessions unoss medial excused
# ‘Allsesions must be compsod wi 60 days
#
# Suecossaty posing a wrten or oral examination wth rade of atoast 70.
#
# pepepe
#
# ‘This Driver improvement Cin wil ot refund any ttn o pert of aon he Clinic is ead, wing an able to fll ts pat
# ‘ofthis contract understand that ffl © comply wih the rms and conditions ofthis agreement. | in breach of contact and the
# ‘school wil not be under any obligation to ful he terms of his contract, and may, at option, ering this agreement immediately
# ‘tis agreed that an une, instucor, or ployee of this Cnc shall ot giveth impression toa sudent that upon completion
# ‘oftheirnstruction tis Cine wil guarentee the securing of adver’ cence o operate a motor voice. However, mediately upon he
# ‘success completion ofthe course as described above, the Clinic agrees to provide cericton of sd completion the
#
# ‘nso chi ees bare ees Der pana Scere ba avec
# snsroetcomemn ane magen
#
# 08 / 15 / 2024 Wallan —Slist ey
# reo Scent aie Signature of Aubrzed Cine Date
#
# Representative
#
# boc ID: a86800bdteee77oco4oased0NdeeHsA85080e6—
#
#
#
# Page 2:
# > Dropbox Sign
#
# Document
# Aura date format
#
# Document History
#
# Gt 08/15/2024
# ser 10:59:56 UTC-4
# ® 08/15/2024
#
# veweo 15:34:29 UTC-4
#
# a 08/15/2024
# sone 153645 UTC-4
# o 08/15/2024
#
# 152645 UTC-4
#
# Pome by 3 Dropbox in
#
# Audit trall
#
# 12559 Aswin Bhaskaran
# 12560.pat
# ‘3e5909bdccc77act4onSas0ad06r4885000a6a
# hm iDD I YYYY
#
# ‘© Signed
#
# ‘Sent for signature to Aswin Bhaskaran (aswinaus@gmall.com)
# {rom atdrvingschools@amai.com
# 1: 73.82.113.86
#
# Viewed by Aswin Bhaskaran (aswinaus@gmail.com)
# 1P: 106.48.104.120
#
# ‘Signed by Aswin Bhaskaran (aswinaus@gmailcom)
# 1P: 106.48.104.120
#
# ‘The document has been completed.
